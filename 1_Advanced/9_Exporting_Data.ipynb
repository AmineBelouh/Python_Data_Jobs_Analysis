# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.head().to_csv('data_jobs_export.csv', index=False)

# %%
df_data_scientist = df[df['job_title_short'] == 'Data Scientist'].copy()

# %%
df_data_scientist.head().to_csv('data_scientist_jobs.csv', index=False)

# %%
df_NY = df[df['job_location'] == 'New York, NY'].copy()

# %%
df_NY.to_excel('new_york_jobs.xlsx', index=False)
